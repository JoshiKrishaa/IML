# %%
#Write a NumPy program to implement following operation
#to convert a list of numeric values into a one-dimensional NumPy array
#Krishaa Joshi
#216270307047
import numpy as np
a=[1,2,3,4,5]
print('list',a)
b=np.array(a)
print("array:",b)

# %%
#Write a NumPy program to implement following operation
#to create a 3x3 matrix with values ranging from 2 to 10
#Krishaa Joshi
#216270307047
import numpy as np
array= np.arange(2,11)
new_array=np.reshape(array,(3,3))
print(new_array)

# %%
#Write a NumPy program to implement following operation
#to append values at the end of an array
#Krishaa Joshi
#216270307047
import numpy as np
from numpy import random
a=[1,2,3,4,5]
print('list',a)
b=random.randint(10)
print("array:",np.append(a,b))

# %%
#Write a NumPy program to implement following operation
#to create another shape from an array without changing its data(3*2to 2*3)
#Krishaa Joshi
#216270307047
import numpy as np
a= np.array([[1, 2], [5, 6],[7,8]])
print("array=",a.reshape(3,2))
print("array=",a.reshape(2,3))
